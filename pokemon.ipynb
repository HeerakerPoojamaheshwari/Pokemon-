# %%
import numpy as ap 
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/hp/Desktop/Pokemon 31.csv")

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# # finding first and last rows

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  Total  HP  Attack  Defense  \
# 795  719              Diancie     Rock  Fairy    600  50     100      150
# 796  719  DiancieMega Diancie     Rock  Fairy    700  50     160      110
# 797  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110       60
# 798  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160       60
# 799  721            Volcanion     Fire  Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True

# %% [markdown]
# # How many columns are there

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# # Check the shape of the dataframe (rows , columns)

# %%
df.shape
# Out:
# (800, 13)

# %% [markdown]
# # Check statistical information about the dataframe

# %%
df.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %% [markdown]
# # How many pokemon are legendary?

# %%
legendary_count = len(df[df['Legendary']])

# %%
legendary_count
# Out:
# 65

# %% [markdown]
# # legendary pokemon by type

# %%
legendary_type = df[(df['Legendary']== True) & df['Type 1']]['Type 1'].value_counts().reset_index(name = 'count')

# %%
legendary_type
# Out:
#        index  count
# 0    Psychic     14
# 1     Dragon     12
# 2       Fire      5
# 3   Electric      4
# 4      Water      4
# 5       Rock      4
# 6      Steel      4
# 7     Ground      4
# 8      Grass      3
# 9        Ice      2
# 10    Normal      2
# 11     Ghost      2
# 12      Dark      2
# 13    Flying      2
# 14     Fairy      1

# %%
legendary_type = df[(df['Legendary']== True) & df['Type 2']]['Type 2'].value_counts().reset_index(name = 'count')

# %%
legendary_type
# Out:
#        index  count
# 0     Flying     13
# 1    Psychic      5
# 2   Fighting      4
# 3     Dragon      4
# 4       Fire      3
# 5        Ice      3
# 6      Fairy      2
# 7      Steel      1
# 8   Electric      1
# 9     Ground      1
# 10     Ghost      1
# 11      Dark      1
# 12     Water      1

# %% [markdown]
# # Legendary pokemon by fighter stats?

# %%
legendary_pokemon= df[df['Legendary']==True][['HP','Attack','Defense','Sp. Def','Speed']]

# %%
legendary_pokemon
# Out:
#       HP  Attack  Defense  Sp. Def  Speed
# 156   90      85      100      125     85
# 157   90      90       85       90    100
# 158   90     100       90       85     90
# 162  106     110       90       90    130
# 163  106     190      100      100    130
# ..   ...     ...      ...      ...    ...
# 795   50     100      150      150     50
# 796   50     160      110      110    110
# 797   80     110       60      130     70
# 798   80     160       60      130     80
# 799   80     110      120       90     70
#
# [65 rows x 5 columns]

# %% [markdown]
# # cleaning the dataset

# %%
#step 1 : Handling missing values 
#check which columns have missing values and how many.
missing_values=df.isnull().sum()

# %%
missing_values
# Out:
# #               0
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
#it appears that "Type 2 "has missing values.
#lets fill those with a reasionable value.
df['Type 2'].fillna('none',inplace=True)

# %%
df['Type 2']
# Out:
# 0      Poison
# 1      Poison
# 2      Poison
# 3      Poison
# 4        none
#         ...
# 795     Fairy
# 796     Fairy
# 797     Ghost
# 798      Dark
# 799     Water
# Name: Type 2, Length: 800, dtype: object

# %%
#check for and remove duplicate rows
df.drop_duplicates(inplace=True)

# %%
print("cleaned dataset")
df.head(5)
# Out:
# cleaned dataset
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire    none    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# # How are pokemon numbers distributed across generations?

# %%
generation_counts=df.groupby('Generation').count()['#']
plt.bar(generation_counts.index,generation_counts.values)
#Add labels and title
plt.xlabel('Generation')
plt.ylabel('Number of Pokemon')
plt.title('Distribution of pokemon across Generations')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # What are the most common types of pokemon?

# %%
types_pokemon=df['Type 1'].value_counts().head(5)

# %%
types_pokemon
# Out:
# Water      112
# Normal      98
# Grass       70
# Bug         69
# Psychic     57
# Name: Type 1, dtype: int64

# %%
types_pokemon=df['Type 2'].value_counts().head(5)

# %%
types_pokemon
# Out:
# none       386
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Name: Type 2, dtype: int64

# %% [markdown]
# # What are the strongest and weakest pokemon species?

# %%
strongest_pokemon=df[df['Total']==df['Total'].max()]

# %%
weakest_pokemon=df[df['Total']==df['Total'].min()]

# %%
strongest_species=strongest_pokemon['Name'].values[0]
weakest_species=weakest_pokemon['Name'].values[0]

# %%
strongest_total=strongest_pokemon['Total'].values[0]
weakest_total=weakest_pokemon['Total'].values[0]

# %%
#print the results
print("The strongest pokemon species is:",strongest_species)
print("Total strength:",strongest_total)
print("The weakest pokemon species is:",weakest_species)
print("Total strength:",weakest_total)
# Out:
# The strongest pokemon species is: MewtwoMega Mewtwo X
# Total strength: 780
# The weakest pokemon species is: Sunkern
# Total strength: 180

# %% [markdown]
# # What are the strongest and weakest types of pokemon?

# %%
type_strength=df.groupby('Type 1')['Total'].mean()
strongest_type=type_strength.index[0]
strongest_average_total=type_strength.iloc[0]

weakest_type= type_strength.index[-1]
weakest_average_total=type_strength.iloc[-1]

# %%
print("The strongest type of pokemon is:",strongest_type)
print("Average total strength:",strongest_average_total)
print("The weakest type of pokemon is:",weakest_type)
print("Average total strength:",weakest_average_total)
# Out:
# The strongest type of pokemon is: Bug
# Average total strength: 378.92753623188406
# The weakest type of pokemon is: Water
# Average total strength: 430.45535714285717

# %% [markdown]
# # Do any types of pokemon excel at certain statistics over others?

# %%
df.groupby('Type 1')['HP','Attack','Defense'].mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26196\2317342879.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Type 1')['HP','Attack','Defense'].mean()
#                  HP      Attack     Defense
# Type 1
# Bug       56.884058   70.971014   70.724638
# Dark      66.806452   88.387097   70.225806
# Dragon    83.312500  112.125000   86.375000
# Electric  59.795455   69.090909   66.295455
# Fairy     74.117647   61.529412   65.705882
# Fighting  69.851852   96.777778   65.925926
# Fire      69.903846   84.769231   67.769231
# Flying    70.750000   78.750000   66.250000
# Ghost     64.437500   73.781250   81.187500
# Grass     67.271429   73.214286   70.800000
# Ground    73.781250   95.750000   84.843750
# Ice       72.000000   72.750000   71.416667
# Normal    77.275510   73.469388   59.846939
# Poison    67.250000   74.678571   68.821429
# Psychic   70.631579   71.456140   67.684211
# ...

# %%
df.groupby('Type 1')['HP','Attack','Defense'].max()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26196\1872921891.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Type 1')['HP','Attack','Defense'].max()
#            HP  Attack  Defense
# Type 1
# Bug        86     185      230
# Dark      126     150      125
# Dragon    125     180      130
# Electric   90     123      115
# Fairy     126     131       95
# Fighting  144     145       95
# Fire      115     160      140
# Flying     85     115       80
# Ghost     150     165      145
# Grass     123     132      131
# Ground    115     180      160
# Ice       110     130      184
# Normal    255     160      126
# Poison    105     106      120
# Psychic   190     190      160
# Rock      123     165      200
# Steel     100     150      230
# Water     170     155      180

# %%
df.groupby('Type 1')['HP','Attack','Defense'].min()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26196\2841493227.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Type 1')['HP','Attack','Defense'].min()
#           HP  Attack  Defense
# Type 1
# Bug        1      10       30
# Dark      35      50       30
# Dragon    41      50       35
# Electric  20      30       15
# Fairy     35      20       28
# Fighting  30      35       30
# Fire      38      30       37
# Flying    40      30       35
# Ghost     20      30       30
# Grass     30      27       30
# Ground    10      40       25
# Ice       36      30       15
# Normal    30       5        5
# Poison    35      43       35
# Psychic   20      20       15
# Rock      30      40       40
# Steel     40      24       50
# Water     20      10       20

# %% [markdown]
# # Correlation between different statistics

# %%
correlation_matrix =df[['Total','HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].corr()

# %%
correlation_matrix
# Out:
#             Total        HP    Attack   Defense   Sp. Atk   Sp. Def     Speed
# Total    1.000000  0.618748  0.736211  0.612787  0.747250  0.717609  0.575943
# HP       0.618748  1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack   0.736211  0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense  0.612787  0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk  0.747250  0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def  0.717609  0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed    0.575943  0.175952  0.381240  0.015227  0.473018  0.259133  1.000000

# %% [markdown]
# # Considerations regarding the results

# %%
#To compare statistics across different types of pokemon:
df.groupby('Type 1').mean()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26196\2186488394.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Type 1').mean()
#                    #       Total         HP      Attack     Defense  \
# Type 1
# Bug       334.492754  378.927536  56.884058   70.971014   70.724638
# Dark      461.354839  445.741935  66.806452   88.387097   70.225806
# Dragon    474.375000  550.531250  83.312500  112.125000   86.375000
# Electric  363.500000  443.409091  59.795455   69.090909   66.295455
# Fairy     449.529412  413.176471  74.117647   61.529412   65.705882
# Fighting  363.851852  416.444444  69.851852   96.777778   65.925926
# Fire      327.403846  458.076923  69.903846   84.769231   67.769231
# Flying    677.750000  485.000000  70.750000   78.750000   66.250000
# ...

# %%
#To create visualizations:
df.plot.scatter(x='Attack',y='Defense')
plt.show()

# %% [markdown]
# # Creating training/test split

# %%
from sklearn.model_selection import train_test_split
#splitting the dataset into training and test sets
train_df,test_df=train_test_split(df,test_size=0.2,random_state=42)

# %%
train_df,test_df
# Out:
# (       #                     Name   Type 1  Type 2  Total   HP  Attack  \
#  264  245                  Suicune    Water    none    580  100      75
#  615  555  DarmanitanStandard Mode     Fire    none    480  105     140
#  329  303        MawileMega Mawile    Steel   Fairy    480   50     105
#  342  313                  Volbeat      Bug    none    400   65      73
#  394  360                   Wynaut  Psychic    none    260   95      23
#  ..   ...                      ...      ...     ...    ...  ...     ...
#  71    65    AlakazamMega Alakazam  Psychic    none    590   55      50
#  106   98                   Krabby    Water    none    325   30     105
#  270  250                    Ho-oh     Fire  Flying    680  106     130
#  435  390                 Chimchar     Fire    none    309   44      58
#  102   94        GengarMega Gengar    Ghost  Poison    600   60      65
#
#       Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# # Splitting the data into training and test sets

# %%
train_df=df.sample(frac=0.8,random_state=42)

# %%
train_df
# Out:
#        #             Name    Type 1    Type 2  Total  HP  Attack  Defense  \
# 696  635        Hydreigon      Dark    Dragon    600  92     105       90
# 667  606         Beheeyem   Psychic      none    485  75      75       75
# 63    58        Growlithe      Fire      none    350  55      70       45
# 533  479  RotomWash Rotom  Electric     Water    520  50      65      107
# 66    61        Poliwhirl     Water      none    385  65      65       65
# ..   ...              ...       ...       ...    ...  ..     ...      ...
# 657  596       Galvantula       Bug  Electric    472  70      77       60
# 472  425         Drifloon     Ghost    Flying    348  90      50       34
# 347  318         Carvanha     Water      Dark    305  45      90       20
# 505  455        Carnivine     Grass      none    454  74     100       72
# 639  578          Duosion   Psychic      none    370  65      40       50
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
test_df=df.drop(train_df.index)

# %%
test_df
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 1      2              Ivysaur    Grass  Poison    405   60      62       63
# 4      4           Charmander     Fire    none    309   39      52       43
# 13    10             Caterpie      Bug    none    195   45      30       35
# 14    11              Metapod      Bug    none    205   50      20       55
# 20    16               Pidgey   Normal  Flying    251   40      45       40
# ..   ...                  ...      ...     ...    ...  ...     ...      ...
# 778  708             Phantump    Ghost   Grass    309   43      70       48
# 782  710  PumpkabooLarge Size    Ghost   Grass    335   54      66       70
# 788  712             Bergmite      Ice    none    304   55      69       85
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...
